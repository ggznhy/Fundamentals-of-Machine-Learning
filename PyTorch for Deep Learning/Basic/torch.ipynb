# %%
import torch
test = torch.tensor([1, 2])
print(test)
# Out:
# tensor([1, 2])

# %%
a = torch.zeros((3, 4))
a.add(7)
# Out:
# tensor([[7., 7., 7., 7.],
#         [7., 7., 7., 7.],
#         [7., 7., 7., 7.]])

# %%
torch.randint(0, 10, (3, 4))
# Out:
# tensor([[3, 5, 4, 9],
#         [9, 8, 7, 7],
#         [3, 5, 8, 8]])

# %%
torch.rand(3, 4)
# Out:
# tensor([[0.4011, 0.3697, 0.4983, 0.5558],
#         [0.6163, 0.3128, 0.4982, 0.8171],
#         [0.8886, 0.5422, 0.9265, 0.3059]])

# %%
import numpy as np
x = np.array([1, 2, 3])
y = torch.tensor(x)
print(type(x), type(y))
# Out:
# <class 'numpy.ndarray'> <class 'torch.Tensor'>

# %%
u = torch.tensor([1.0, 2.0, 3.0])
v = u.view(3, 1)
u, v
# Out:
# (tensor([1., 2., 3.]),
#  tensor([[1.],
#          [2.],
#          [3.]]))

# %%
# gradient tracking
xx = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
print(xx)  # None
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
out = xx.pow(3).sum()
out.backward()
print(xx.grad)  # gradient
# Out:
# tensor([ 3., 12., 27.])
